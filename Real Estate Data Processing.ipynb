# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SayD'

# %%
os.chdir("C:\\Users\\SayD\\Desktop\\Mini Project")

# %%
data = pd.read_csv("Database.csv")  # Replace with the actual file path

# %%
data.head()
# Out:
#        LOCATION                 BROKERS  CONTACT INFO PROPERTY TYPE  \
# 0     Rahatgaon      Pandit Real Estate    9684861654          Plot
# 1  Chandi Chowk  Affinity International    9684861654          Flat
# 2       Tapovan      All Amravati Group    9684861654          Plot
# 3       Badnera      Atlas Realty Group    9684861654          Flat
# 4  Dastur Nagar       Better Properties    9684861654          Flat
#
#   DIMENSIONS      COSTING
# 0   3000sqft  1,00,00,000
# 1       2BHK    30,00,000
# 2   1800sqft    40,00,000
# 3       1BHK    18,00,000
# 4        1RK    15,00,000

# %%
data.tail()
# Out:
#          LOCATION                  BROKERS  CONTACT INFO PROPERTY TYPE  \
# 95    Gopal Nagar        Azure Crest Homes    9865091766          Flat
# 96    Cover Nagar    Crown Enclave Estates    9649263054          Farm
# 97  Pathaan Chowk  Elysian View Properties    9152374985          Plot
# 98     Panchavati           Serene Heights    9273507450          Farm
# 99    Shaam Chowk  Celestial Crest Estates    9407346226          Farm
#
#    DIMENSIONS       COSTING
# 95       2BHK     35,00,000
# 96   20 Acres  15,00,00,000
# 97   1800sqft     24,00,000
# 98   15 Acres  35,00,00,000
# 99    8 Acres  25,00,00,000

# %%
data.describe()
# Out:
#        CONTACT INFO
# count  1.000000e+02
# mean   9.542856e+09
# std    2.634125e+08
# min    9.012592e+09
# 25%    9.321842e+09
# 50%    9.684759e+09
# 75%    9.684862e+09
# max    9.944462e+09

# %%
data.ndim
# Out:
# 2

# %%
desired_location = 'Rahatgaon'
matching_rows = data[data['LOCATION']==desired_location]
print(matching_rows)
# Out:
#      LOCATION             BROKERS  CONTACT INFO PROPERTY TYPE DIMENSIONS  \
# 0   Rahatgaon  Pandit Real Estate    9684861654          Plot   3000sqft
# 12  Rahatgaon           Flat Free    9684861654          Farm   12 Acres
# 19  Rahatgaon       Meadows Group    9684861654          Flat       2BHK
# 62  Rahatgaon         Crown Elite    9888857829          Plot   1800sqft
#
#          COSTING
# 0    1,00,00,000
# 12  40,00,00,000
# 19     35,00,000
# 62     40,00,000

# %%
desired_location = '40,00,000'
matching_rows = data[data['COSTING']==desired_location]
print(matching_rows)
# Out:
#      LOCATION                BROKERS  CONTACT INFO PROPERTY TYPE DIMENSIONS  \
# 2     Tapovan     All Amravati Group    9684861654          Plot   1800sqft
# 32      Camp   Elite Enclave Estates    9442976775          Plot   1800sqft
# 62  Rahatgaon            Crown Elite    9888857829          Plot   1800sqft
#
#       COSTING
# 2   40,00,000
# 32  40,00,000
# 62  40,00,000

# %%
desired_location = 'Plot'
matching_rows = data[data['PROPERTY TYPE']==desired_location]
print(matching_rows)
# Out:
#             LOCATION                         BROKERS  CONTACT INFO  \
# 0          Rahatgaon              Pandit Real Estate    9684861654
# 2            Tapovan              All Amravati Group    9684861654
# 5    Paradise Colony                        Blue One    9684861654
# 8      Nemani Colony                     Continental    9684861654
# 10           Tapovan               Empire Properties    9684861654
# 13      Chandi Chowk                   Full Spectrum    9684861654
# 15   Sunshine Colony                       HomeSmart    9684861654
# 17         Paratwada  Lifestyle International Realty    9684861654
# 18     Nemani Colony               Marketplace Homes    9684861654
# 21      Dastur Nagar       Nationwide Title Clearing    9684861654
# 24       Radha Nagar                       PC Realty    9684861654
# 25     Circuit House            Prestige Consultancy    9684861654
# 26         Sai Nagar               Ready Real Estate    9684861654
# ...

# %%
data.isna()
# Out:
#     LOCATION  BROKERS  CONTACT INFO  PROPERTY TYPE  DIMENSIONS  COSTING
# 0      False    False         False          False       False    False
# 1      False    False         False          False       False    False
# 2      False    False         False          False       False    False
# 3      False    False         False          False       False    False
# 4      False    False         False          False       False    False
# ..       ...      ...           ...            ...         ...      ...
# 95     False    False         False          False       False    False
# 96     False    False         False          False       False    False
# 97     False    False         False          False       False    False
# 98     False    False         False          False       False    False
# 99     False    False         False          False       False    False
#
# [100 rows x 6 columns]

# %%
data.isna().any()
# Out:
# LOCATION         False
# BROKERS          False
# CONTACT INFO     False
# PROPERTY TYPE    False
# DIMENSIONS       False
# COSTING          False
# dtype: bool
